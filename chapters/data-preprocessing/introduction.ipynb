# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/cars/cars.csv')

# %%
df
# Out:
#              Make Model  Color             Body_Type      Production_Date  \
# 0      Volkswagen  Golf   Grey             Hatchback  1999-07-01 00:00:00
# 1      Volkswagen  Golf    Red                Cabrio  2000-05-01 00:00:00
# 2      Volkswagen  Golf    Red                Cabrio  2000-05-01 00:00:00
# 3      Volkswagen  Golf  White                Cabrio  1981-02-01 00:00:00
# 4      Volkswagen  Golf  White                Cabrio  1981-02-01 00:00:00
# ...           ...   ...    ...                   ...                  ...
# 15846        Audi    A3  Black             Hatchback           2026-01-01
# 15847        Audi    Q7  Green  SUV/Off-Road/Pick-Up           2026-01-01
# 15848        Audi    Q8  Black  SUV/Off-Road/Pick-Up           2026-01-01
# 15849        Audi    A6   Grey          Stationwagen           2026-01-01
# 15850        Audi    A6   Blue          Stationwagen           2026-01-01
#
#       Drive_Type Transmission   Mileage Emission_Class  Power  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Color', 'Body_Type', 'Production_Date', 'Drive_Type',
#        'Transmission', 'Mileage', 'Emission_Class', 'Power',
#        'Engine_Displacement', 'Build_Year', 'Fuel', 'Category', 'Seats',
#        'Doors', 'Gears', 'Cylinders', 'Curb_Weight', 'CO2_Emission',
#        'Interior_Material', 'Price', 'Interior_Color', 'Paint_Type',
#        'Technical_Inspection', 'Production_Year', 'Non_Smoker_Car',
#        'Fuel_Consumption', 'Warranty', 'Last_Service', 'Electric_Range',
#        'Other_Energy_Sources'],
#       dtype='object')

# %%
df['Price']
# Out:
# 0          1195.0
# 1          9950.0
# 2          9950.0
# 3          7450.0
# 4          7450.0
#            ...
# 15846     39995.0
# 15847    132940.0
# 15848    129980.0
# 15849     80790.0
# 15850     84898.0
# Name: Price, Length: 15851, dtype: float64
